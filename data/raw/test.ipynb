# %%
import pandas as pd
import numpy as np

EQ_DATA = pd.read_csv("all_month.csv")
EQ_DATA.sample(10)
# Out:
#                           time   latitude   longitude     depth   mag magType  \
# 4579  2025-10-05T19:39:24.911Z -23.421600  179.006800  572.0930  4.60      mb
# 1719  2025-10-16T10:58:23.410Z  33.891333 -117.214500   13.2900  0.76      ml
# 5959  2025-10-01T04:39:41.426Z  61.986600 -148.181700   39.0000  1.10      ml
# 361   2025-10-22T00:52:45.415Z  31.953000 -103.357000    6.3049  1.40      ml
# 5220  2025-10-03T16:24:10.458Z   2.011000  126.661300   42.8380  4.60      mb
# 6775  2025-09-28T18:30:02.209Z  35.553333  -96.752667    5.8900 -0.18      ml
# 3048  2025-10-11T04:01:34.240Z  36.959999 -121.589836    5.2700  1.45      md
# 159   2025-10-22T23:27:16.310Z  35.042000 -117.676333   -0.8200  1.89      ml
# 8241  2025-09-24T08:56:56.370Z  45.976000 -122.535000   15.8300  0.19      ml
# 4306  2025-10-06T19:22:27.050Z  33.183667 -116.425833    4.1500  0.46      ml
#
#        nst    gap      dmin   rms  ...                   updated  \
# ...
