# %%
import pandas as pd
import numpy as np
import altair as alt

# %%
cleaned_df = pd.read_csv('../data/processed/cleaned_data.csv')
cleaned_df.head()
# Out:
#                        time   latitude   longitude   depth   mag magType  \
# 0  2025-10-23T22:11:40.587Z  32.274000 -101.931000  4.2122  1.40      ml
# 1  2025-10-23T22:09:24.260Z  38.806835 -122.751999 -0.6400  1.27      md
# 2  2025-10-23T22:08:01.540Z  38.807835 -122.751167  0.1900  1.24      md
# 3  2025-10-23T22:07:48.630Z  38.834332 -122.796333  2.2500  0.23      md
# 4  2025-10-23T22:01:31.590Z  38.808998 -122.811668  3.6600  0.74      md
#
#     nst    gap      dmin   rms  ...                   updated  \
# 0  40.0   40.0  0.000000  0.50  ...  2025-10-23T22:15:58.438Z
# 1  13.0  110.0  0.023310  0.04  ...  2025-10-23T22:11:02.859Z
# 2  12.0  112.0  0.023690  0.02  ...  2025-10-23T22:09:37.818Z
# 3  10.0   76.0  0.006201  0.02  ...  2025-10-23T22:09:23.246Z
# 4  10.0   83.0  0.012830  0.02  ...  2025-10-23T22:03:07.964Z
#
#                         place        type horizontalError depthError  \
# 0  20 km NW of Stanton, Texas  earthquake            0.00   0.813793
# 1         3 km SW of Cobb, CA  earthquake            0.25   0.730000
# 2        3 km WSW of Cobb, CA  earthquake            0.23   1.030000
# 3        6 km WNW of Cobb, CA  earthquake            0.57   0.460000
# 4  6 km NW of The Geysers, CA  earthquake            0.40   1.180000
#
#    magError  magNst     status  locationSource magSource
# 0      0.20    25.0  automatic              tx        tx
# 1      0.21    13.0  automatic              nc        nc
# 2      0.21    12.0  automatic              nc        nc
# 3      0.11    10.0  automatic              nc        nc
# 4      0.07    10.0  automatic              nc        nc
#
# [5 rows x 22 columns]

# %%
cleaned_df.shape
# Out:
# (6281, 22)

# %% [markdown]
# Box chart on mag

# %%
alt.data_transformers.enable('default', max_rows=None)
mag_box_chart = alt.Chart(cleaned_df).mark_boxplot(
    median={'color':'red'},
    extent = 5,
    ticks=True
).encode(
    alt.Y('mag:Q', title='Magnitude')
).properties(width=300, height=300, title='Boxplot on Magnitude')

gap_box_chart = alt.Chart(cleaned_df).mark_boxplot(
    median={'color':'red'},
    extent = 5,
    ticks=True
).encode(
    alt.Y('gap:Q', title='Gap')
).properties(width=300, height=300, title='Boxplot on Gap')


(mag_box_chart | gap_box_chart).resolve_scale( y = 'independent')
# Out:
# alt.HConcatChart(...)

# %% [markdown]
# Mag quantail data

# %%
s = cleaned_df['mag']

q = s.quantile([0.25, 0.5, 0.75])
q1, med, q3 = q.loc[0.25], q.loc[0.5], q.loc[0.75]
iqr = q3 - q1

lower_whisker = s[s >= q1 - 1.5*iqr].min()
upper_whisker = s[s <= q3 + 1.5*iqr].max()

print(f"Q1 = {q1:.4f}")
print(f"Median = {med:.4f}")
print(f"Q3 = {q3:.4f}")
# Out:
# Q1 = 0.7600
# Median = 1.2700
# Q3 = 1.9600

# %% [markdown]
# Gap quantail data

# %%
s = cleaned_df['gap']

q = s.quantile([0.25, 0.5, 0.75])
q1, med, q3 = q.loc[0.25], q.loc[0.5], q.loc[0.75]
iqr = q3 - q1

lower_whisker = s[s >= q1 - 1.5*iqr].min()
upper_whisker = s[s <= q3 + 1.5*iqr].max()

print(f"Q1 = {q1:.4f}")
print(f"Median = {med:.4f}")
print(f"Q3 = {q3:.4f}")
# Out:
# Q1 = 61.0000
# Median = 85.0000
# Q3 = 130.0000

# %% [markdown]
# Mag and Gap ordinal transformation

# %%
mag_bins   = [-np.inf, 0.76, 1.27, 1.96, np.inf]  
mag_labels = ['D', 'C', 'B', 'A']
cleaned_df['mag_level'] = pd.cut(
    cleaned_df['mag'],
    bins=mag_bins,
    labels=mag_labels,
    right=False,
    include_lowest=True
)

gap_bins   = [-np.inf, 61, 85, 130, np.inf]
gap_labels = ['high', 'moderate-high', 'moderate-low', 'poor'] 
cleaned_df['gap_level'] = pd.cut(
    cleaned_df['gap'],
    bins=gap_bins,
    labels=gap_labels,
    right=False,
    include_lowest=True
)


cleaned_df.sample(10)
# Out:
#                           time   latitude   longitude   depth   mag magType  \
# 1725  2025-10-14T15:40:29.530Z  38.792667 -122.754997   0.170  0.83      md
# 1768  2025-10-14T10:09:19.180Z  38.823502 -122.842331   1.930  1.30      md
# 4197  2025-10-03T06:35:17.300Z  44.576667 -112.225500   6.110  1.51      ml
# 1038  2025-10-18T01:15:43.630Z  35.397167 -117.758167   6.910  1.42      ml
# 3505  2025-10-06T08:42:52.020Z  33.027833 -116.292500   6.110  0.74      ml
# 5468  2025-09-27T08:30:23.409Z  -6.682500  132.221400  10.000  4.60      mb
# 1410  2025-10-16T06:48:26.047Z  42.902500 -111.226200  10.964  2.90      ml
# 5863  2025-09-25T13:56:14.660Z  38.817665 -122.818497   2.890  0.75      md
# 2106  2025-10-12T18:29:56.440Z  57.872333 -156.892500  18.950  0.65      ml
# 2341  2025-10-11T10:45:35.200Z  35.929001 -120.477501   3.850  1.15      md
#
#        nst    gap      dmin   rms  ...        type horizontalError depthError  \
# 1725   9.0   85.0  0.017110  0.03  ...  earthquake            0.32      0.980
# 1768  21.0  101.0  0.005716  0.02  ...  earthquake            0.23      0.320
# 4197  29.0   96.0  0.121800  0.15  ...  earthquake            0.38      2.440
# 1038  44.0   32.0  0.103000  0.15  ...  earthquake            0.14      0.420
# 3505  45.0   44.0  0.073600  0.18  ...  earthquake            0.20      0.580
# 5468  29.0  100.0  3.739000  0.75  ...  earthquake            8.44      1.882
# 1410  44.0   58.0  0.655000  0.35  ...  earthquake            1.75      8.458
# 5863   6.0  104.0  0.012120  0.02  ...  earthquake            0.56      1.420
# 2106   4.0  196.0  0.125200  0.04  ...  earthquake            0.72      1.100
# 2341  16.0   68.0  0.018280  0.05  ...  earthquake            0.30      0.480
#
#       magError magNst     status  locationSource  magSource  mag_level  \
# 1725  0.120000    8.0  automatic              nc         nc          C
# 1768  0.070000   20.0  automatic              nc         nc          B
# 4197  0.159255   33.0   reviewed              mb         mb          B
# 1038  0.181000   26.0   reviewed              ci         ci          B
# 3505  0.141000   40.0   reviewed              ci         ci          D
# 5468  0.119000   21.0   reviewed              us         us          A
# 1410  0.038000   90.0   reviewed              us         us          A
# 5863  0.300000    9.0  automatic              nc         nc          D
# 2106  0.250687    4.0   reviewed              av         av          D
# 2341  0.180000    6.0  automatic              nc         nc          C
#
#           gap_level
# 1725   moderate-low
# 1768   moderate-low
# 4197   moderate-low
# 1038           high
# 3505           high
# 5468   moderate-low
# 1410           high
# 5863   moderate-low
# 2106           poor
# 2341  moderate-high
#
# [10 rows x 24 columns]

# %%
cleaned_df.to_csv("../data/processed/cleaned_data_ordinal_level.csv", index=False)
